# %% [markdown]
# ## One-click Notebook

# %%
# !curl -s -OL https://raw.githubusercontent.com/StephenZou-bot/sd-webui-notebook/main/res/one-click/main.py

# !python main.py --ngrok_token "ngrok_token_here" --pastebin "https://pastebin.com/XahpVjuT"
